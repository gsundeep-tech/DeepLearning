# %%
#importing libraries
import numpy as np

# %%
# downloading MNIST datasets
def download_dataset():
    
    from urllib.request import urlretrieve
    from os.path import isfile, isdir
    from tqdm import tqdm
    import tarfile


    cifar10_dataset_folder_path = 'cifar-10-batches-py'
    tar_gz_path = 'cifar-10-python.tar.gz'

    class DLProgress(tqdm):
        last_block = 0

        def hook(self, block_num=1, block_size=1, total_size=None):
            self.total = total_size
            self.update((block_num - self.last_block) * block_size)
            self.last_block = block_num

    if not isfile(tar_gz_path):
        with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
            urlretrieve(
                'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
                tar_gz_path,
                pbar.hook)

    if not isdir(cifar10_dataset_folder_path):
        with tarfile.open(tar_gz_path) as tar:
            tar.extractall()
            tar.close()

# %%
#preprocess the images dataset
cifar10_dataset_folder_path = 'cifar-10-batches-py'

def one_hot_encoding(x):
    
    n_values = 10
    return np.eye(n_values)[x]

def normalize(x):
    
    return x/255

def load_images_labels():
    
    import pickle
    from sklearn.utils import shuffle
    
    batch_ids = 5
    train_validation_dataset = []
    
    for batch_id in range(1, batch_ids + 1):
        with open(cifar10_dataset_folder_path + "/data_batch_" + str(batch_id), mode='rb' ) as file:
            batch = pickle.load(file, encoding='latin1')
            for data, label in zip(batch['data'], batch['labels']):
                train_validation_dataset.append((normalize(data), one_hot_encoding(label)))
    
    test_dataset = []
    with open(cifar10_dataset_folder_path + "/test_batch", mode='rb') as file:
        for data, label in zip(batch['data'], batch['labels']):
            test_dataset.append((normalize(data), one_hot_encoding(label)))
            
    return shuffle(shuffle(train_validation_dataset)), test_dataset

def extract_images_labels(images_labels):
    
    images = np.array([x[0] for x in images_labels])
    labels = np.array([x[1] for x in images_labels])
    
    return images, labels

# %%
download_dataset()
train_val_dataset, test_dataset = load_images_labels()
train_images, train_labels = extract_images_labels(train_val_dataset)
test_images, test_labels = extract_images_labels(test_dataset)

# %%
class NeuralNetwork:
    
    def __init__(self, inputs, hidden_layer1, hidden_layer2, outputs, batch_size=10000, learning_rate=0.1, epochs=100):
        
        self.input_nodes = inputs
        self.hidden_layer1_nodes = hidden_layer1
        self.hidden_layer2_nodes = hidden_layer2
        self.output_nodes = outputs
        
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.epochs = epochs
        
        self.weights_input_to_hidden = np.random.normal(0.0, self.input_nodes**-0.5, (self.input_nodes, self.hidden_layer1_nodes))
        self.weights_hidden_to_hidden = np.random.normal(0.0, self.hidden_layer1_nodes**-0.5, (self.hidden_layer1_nodes, self.hidden_layer2_nodes))
        self.weights_hidden_to_output = np.random.normal(0.0, self.hidden_layer2_nodes**-0.5, (self.hidden_layer2_nodes, self.output_nodes))

        
    def sigmoid(self, x):
        
        return 1/(1 + np.exp(-x))
    
    def sigmoid_prime(self, x):
        
        return self.sigmoid(x) * (1 - self.sigmoid(x))
        
    def train_complete(self, images, targets):
        
        num_records = len(images)
        for i in range(self.epochs):
            
            delta_weights_input_to_hidden = np.zeros(self.weights_input_to_hidden.shape)
            delta_weights_hidden_to_hidden = np.zeros(self.weights_hidden_to_hidden.shape)
            delta_weights_hidden_to_output = np.zeros(self.weights_hidden_to_output.shape)
            
            # forward pass
            weights_hidden_layer1_in, weights_hidden_layer1_out, weights_hidden_layer2_in, \
                    weights_hidden_layer2_out, output_layer_in, final_outputs = self.forward_pass(images)
            
            # backpropagation
            delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, \
                        delta_weights_hidden_to_output = self.backpropagation(images, targets, weights_hidden_layer1_in, \
                        weights_hidden_layer1_out, weights_hidden_layer2_in, weights_hidden_layer2_out, output_layer_in, final_outputs, \
                        delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, delta_weights_hidden_to_output)
            
            # Updating the weights
            self.update_weights(delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, delta_weights_hidden_to_output, num_records)
            
            # Calculating the error
            train_error = self.calculate_error(final_outputs, targets)
            validation_error, validation_accuracy = self.calculate_validation_stats()
            print("Epoch {0}, Training Error {1:0.3f}, Validation Error {2:0.3f}, Validation Accuracy {3:0.3f}".format(i, train_error, validation_error, validation_accuracy))
            
                
    def train_batches(self, images, targets):
        
        num_records = len(images)
        for i in range(self.epochs):
            
            #computing the batches
            for j in range(0, num_records, self.batch_size):
                
                batch_images = images[j: j + self.batch_size]
                batch_targets = targets[j: j + self.batch_size]
                
                delta_weights_input_to_hidden = np.zeros(self.weights_input_to_hidden.shape)
                delta_weights_hidden_to_hidden = np.zeros(self.weights_hidden_to_hidden.shape)
                delta_weights_hidden_to_output = np.zeros(self.weights_hidden_to_output.shape)

                # do the forward pass
                weights_hidden_layer1_in, weights_hidden_layer1_out, weights_hidden_layer2_in, \
                        weights_hidden_layer2_out, output_layer_in, final_outputs = self.forward_pass(batch_images)
                
                # do the backpropagation
                delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, \
                        delta_weights_hidden_to_output = self.backpropagation(batch_images, batch_targets, weights_hidden_layer1_in, \
                        weights_hidden_layer1_out, weights_hidden_layer2_in,weights_hidden_layer2_out, output_layer_in, final_outputs, \
                        delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, delta_weights_hidden_to_output)
                
                # Update the weights
                self.update_weights(delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, delta_weights_hidden_to_output, num_records)
                
                # Calculating the error
                train_error = self.calculate_error(final_outputs, batch_targets)
                validation_error, validation_accuracy = self.calculate_validation_stats()
                print("Epoch {0}, Training Error {1:0.3f}, Validation Error {2:0.3f}, Validation Accuracy {3:0.3f}".format(i, \
                                                                    train_error, validation_error, validation_accuracy))
                
                                      
    def forward_pass(self, features):
        
        weights_hidden_layer1_in = np.dot(features, self.weights_input_to_hidden)
        weights_hidden_layer1_out = self.sigmoid(weights_hidden_layer1_in)
        
        weights_hidden_layer2_in = np.dot(weights_hidden_layer1_out, self.weights_hidden_to_hidden)
        weights_hidden_layer2_out = self.sigmoid(weights_hidden_layer2_in)
        
        output_layer_in = np.dot(weights_hidden_layer2_out, self.weights_hidden_to_output)
        final_outputs = self.sigmoid(output_layer_in)
        
        return weights_hidden_layer1_in, weights_hidden_layer1_out, weights_hidden_layer2_in, \
                weights_hidden_layer2_out, output_layer_in, final_outputs
    
    def backpropagation(self, features, labels, weights_hidden_layer1_in, weights_hidden_layer1_out, weights_hidden_layer2_in, \
                              weights_hidden_layer2_out, output_layer_in, final_outputs, \
                              delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, delta_weights_hidden_to_output):

        """ 
        Note: Error in output layer is the difference of predicted outputs to actual outputs
              Error term would be the derivate of the activation function used in that layer. 
              Eg: x -> y -> z=f(y) here the activation function would be z. so error term would be error * f'(y)
                  in case of sigmoid error * sig(y) * (1- sig(y)) ; here z = sig(y)
                  so we can directly write error * z * (1-z) 
        """
        
        error = labels - final_outputs
        output_error_term = error * self.sigmoid_prime(output_layer_in)
        
        hidden_layer2_error = np.dot(output_error_term, self.weights_hidden_to_output.T)
        # we can also use the sigmoid prime method. here we are using direcly output of hidden layer
        hidden_layer2_error_term = hidden_layer2_error * weights_hidden_layer2_out * (1 - weights_hidden_layer2_out) 
        
        hidden_layer1_error = np.dot(hidden_layer2_error_term, self.weights_hidden_to_hidden.T)
        # third way of writing the error term
        hidden_layer1_error_term = hidden_layer1_error * self.sigmoid(weights_hidden_layer1_in) * (1 - self.sigmoid(weights_hidden_layer1_in))
        
        delta_weights_input_to_hidden += np.dot( features.T,  hidden_layer1_error_term )
        delta_weights_hidden_to_hidden += np.dot(weights_hidden_layer1_out.T , hidden_layer2_error_term )
        delta_weights_hidden_to_output += np.dot(weights_hidden_layer2_out.T , output_error_term)
        
        return delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, delta_weights_hidden_to_output
    
    def update_weights(self, delta_weights_input_to_hidden, delta_weights_hidden_to_hidden, delta_weights_hidden_to_output, num_records):
        
        self.weights_input_to_hidden += self.learning_rate * delta_weights_input_to_hidden / num_records
        self.weights_hidden_to_hidden += self.learning_rate * delta_weights_hidden_to_hidden / num_records
        self.weights_hidden_to_output +=  self.learning_rate * delta_weights_hidden_to_output / num_records
    
    def calculate_error(self, final_outputs, labels):
        error = (labels - final_outputs)**2
        mean_error = np.sum(error)/labels.shape[0]
        
        return mean_error
                      
    def calculate_validation_stats(self):
        
        validation_results = self.test(self.validation_features)
        validation_error = (self.validation_targets - validation_results)**2
        mean_validation_error = np.sum(validation_error)/self.validation_targets.shape[0]
        
        check_max = (validation_results == validation_results.max(axis=1)[:,None])
        check_greater_than_80 = validation_results >= 0.8
        both_conditions = check_max & check_greater_than_80
        
        round_validation_results = both_conditions.astype(int)
        labels_int = self.validation_targets.astype(int)
        num_errors = np.count_nonzero(np.sum(round_validation_results - labels_int, axis=1))
        correct = self.validation_targets.shape[0] - num_errors
        validation_accuracy = correct / self.validation_targets.shape[0]
        
        return mean_validation_error, validation_accuracy
        
    def test(self, features):
        
        weights_hidden_layer1_in = np.dot(features, self.weights_input_to_hidden)
        weights_hidden_layer1_out = self.sigmoid(weights_hidden_layer1_in)
        
        weights_hidden_layer2_in = np.dot(weights_hidden_layer1_out, self.weights_hidden_to_hidden)
        weights_hidden_layer2_out = self.sigmoid(weights_hidden_layer2_in)
        
        output_layer_in = np.dot(weights_hidden_layer2_out, self.weights_hidden_to_output)
        final_outputs = self.sigmoid(output_layer_in)
        
        return final_outputs
    
    def run(self, features, targets):
        
        import timeit

        from sklearn.model_selection import train_test_split
        X_train, X_val, y_train, y_val = train_test_split( features, targets, test_size=0.2, random_state=42)
        
        self.validation_features = X_val
        self.validation_targets = y_val

#         start = timeit.timeit()
#         self.train_complete(X_train, y_train)
#         end = timeit.timeit()
#         print("Time for training Neural Network using Complete batch: {0}".format(end - start)) 
        
        start = timeit.timeit()
        self.train_batches(X_train, y_train)
        end = timeit.timeit()
        print("Time for training Neural Network using mini batches: {0}".format(end - start))

# %%
network = NeuralNetwork(3072, 128, 32, 10)

# %%
network.run(train_images, train_labels)
# Out:
# Epoch 0, Training Error 2.732, Validation Error 2.743, Validation Accuracy 0.000
# Epoch 0, Training Error 2.741, Validation Error 2.741, Validation Accuracy 0.000
# Epoch 0, Training Error 2.753, Validation Error 2.740, Validation Accuracy 0.000
# Epoch 0, Training Error 2.749, Validation Error 2.738, Validation Accuracy 0.000
# Epoch 0, Training Error 2.733, Validation Error 2.737, Validation Accuracy 0.000
# Epoch 0, Training Error 2.742, Validation Error 2.735, Validation Accuracy 0.000
# Epoch 0, Training Error 2.740, Validation Error 2.733, Validation Accuracy 0.000
# Epoch 0, Training Error 2.743, Validation Error 2.732, Validation Accuracy 0.000
# Epoch 0, Training Error 2.735, Validation Error 2.730, Validation Accuracy 0.000
# Epoch 0, Training Error 2.708, Validation Error 2.728, Validation Accuracy 0.000
# Epoch 0, Training Error 2.730, Validation Error 2.727, Validation Accuracy 0.000
# Epoch 0, Training Error 2.729, Validation Error 2.725, Validation Accuracy 0.000
# Epoch 0, Training Error 2.738, Validation Error 2.724, Validation Accuracy 0.000
# Epoch 0, Training Error 2.718, Validation Error 2.722, Validation Accuracy 0.000
# Epoch 0, Training Error 2.713, Validation Error 2.720, Validation Accuracy 0.000
# Epoch 0, Training Error 2.695, Validation Error 2.719, Validation Accuracy 0.000
# Epoch 0, Training Error 2.733, Validation Error 2.717, Validation Accuracy 0.000
# Epoch 0, Training Error 2.718, Validation Error 2.716, Validation Accuracy 0.000
# Epoch 0, Training Error 2.732, Validation Error 2.714, Validation Accuracy 0.000
# Epoch 0, Training Error 2.711, Validation Error 2.712, Validation Accuracy 0.000
# Epoch 0, Training Error 2.710, Validation Error 2.711, Validation Accuracy 0.000
# Epoch 0, Training Error 2.714, Validation Error 2.709, Validation Accuracy 0.000
# Epoch 0, Training Error 2.694, Validation Error 2.708, Validation Accuracy 0.000
# Epoch 0, Training Error 2.706, Validation Error 2.706, Validation Accuracy 0.000
# Epoch 0, Training Error 2.713, Validation Error 2.704, Validation Accuracy 0.000
# Epoch 0, Training Error 2.705, Validation Error 2.703, Validation Accuracy 0.000
# Epoch 0, Training Error 2.699, Validation Error 2.701, Validation Accuracy 0.000
# Epoch 0, Training Error 2.694, Validation Error 2.700, Validation Accuracy 0.000
# Epoch 0, Training Error 2.702, Validation Error 2.698, Validation Accuracy 0.000
# Epoch 0, Training Error 2.691, Validation Error 2.696, Validation Accuracy 0.000
# Epoch 0, Training Error 2.710, Validation Error 2.695, Validation Accuracy 0.000
# Epoch 0, Training Error 2.687, Validation Error 2.693, Validation Accuracy 0.000
# Epoch 0, Training Error 2.688, Validation Error 2.692, Validation Accuracy 0.000
# Epoch 0, Training Error 2.687, Validation Error 2.690, Validation Accuracy 0.000
# Epoch 0, Training Error 2.696, Validation Error 2.688, Validation Accuracy 0.000
# Epoch 0, Training Error 2.686, Validation Error 2.687, Validation Accuracy 0.000
# Epoch 0, Training Error 2.693, Validation Error 2.685, Validation Accuracy 0.000
# Epoch 0, Training Error 2.678, Validation Error 2.684, Validation Accuracy 0.000
# Epoch 0, Training Error 2.681, Validation Error 2.682, Validation Accuracy 0.000
# Epoch 0, Training Error 2.680, Validation Error 2.681, Validation Accuracy 0.000
# Epoch 0, Training Error 2.694, Validation Error 2.679, Validation Accuracy 0.000
# Epoch 0, Training Error 2.670, Validation Error 2.677, Validation Accuracy 0.000
# Epoch 0, Training Error 2.671, Validation Error 2.676, Validation Accuracy 0.000
# Epoch 0, Training Error 2.664, Validation Error 2.674, Validation Accuracy 0.000
# Epoch 0, Training Error 2.675, Validation Error 2.673, Validation Accuracy 0.000
# Epoch 0, Training Error 2.669, Validation Error 2.671, Validation Accuracy 0.000
# Epoch 0, Training Error 2.669, Validation Error 2.670, Validation Accuracy 0.000
# Epoch 0, Training Error 2.674, Validation Error 2.668, Validation Accuracy 0.000
# Epoch 0, Training Error 2.684, Validation Error 2.666, Validation Accuracy 0.000
# Epoch 0, Training Error 2.661, Validation Error 2.665, Validation Accuracy 0.000
# Epoch 0, Training Error 2.663, Validation Error 2.663, Validation Accuracy 0.000
# Epoch 0, Training Error 2.665, Validation Error 2.662, Validation Accuracy 0.000
# Epoch 0, Training Error 2.660, Validation Error 2.660, Validation Accuracy 0.000
# Epoch 0, Training Error 2.646, Validation Error 2.659, Validation Accuracy 0.000
# Epoch 0, Training Error 2.666, Validation Error 2.657, Validation Accuracy 0.000
# Epoch 0, Training Error 2.636, Validation Error 2.656, Validation Accuracy 0.000
# Epoch 0, Training Error 2.659, Validation Error 2.654, Validation Accuracy 0.000
# Epoch 0, Training Error 2.659, Validation Error 2.652, Validation Accuracy 0.000
# Epoch 0, Training Error 2.660, Validation Error 2.651, Validation Accuracy 0.000
# Epoch 0, Training Error 2.664, Validation Error 2.649, Validation Accuracy 0.000
# Epoch 0, Training Error 2.653, Validation Error 2.648, Validation Accuracy 0.000
# Epoch 0, Training Error 2.631, Validation Error 2.646, Validation Accuracy 0.000
# Epoch 0, Training Error 2.647, Validation Error 2.645, Validation Accuracy 0.000
# Epoch 0, Training Error 2.647, Validation Error 2.643, Validation Accuracy 0.000
# Epoch 0, Training Error 2.624, Validation Error 2.642, Validation Accuracy 0.000
# Epoch 0, Training Error 2.633, Validation Error 2.640, Validation Accuracy 0.000
# Epoch 0, Training Error 2.636, Validation Error 2.639, Validation Accuracy 0.000
# Epoch 0, Training Error 2.641, Validation Error 2.637, Validation Accuracy 0.000
# Epoch 0, Training Error 2.616, Validation Error 2.636, Validation Accuracy 0.000
# Epoch 0, Training Error 2.622, Validation Error 2.634, Validation Accuracy 0.000
# Epoch 0, Training Error 2.626, Validation Error 2.632, Validation Accuracy 0.000
# Epoch 0, Training Error 2.629, Validation Error 2.631, Validation Accuracy 0.000
# Epoch 0, Training Error 2.632, Validation Error 2.629, Validation Accuracy 0.000
# Epoch 0, Training Error 2.630, Validation Error 2.628, Validation Accuracy 0.000
# Epoch 0, Training Error 2.644, Validation Error 2.626, Validation Accuracy 0.000
# Epoch 0, Training Error 2.610, Validation Error 2.625, Validation Accuracy 0.000
# Epoch 0, Training Error 2.616, Validation Error 2.623, Validation Accuracy 0.000
# Epoch 0, Training Error 2.595, Validation Error 2.622, Validation Accuracy 0.000
# Epoch 0, Training Error 2.606, Validation Error 2.620, Validation Accuracy 0.000
# Epoch 0, Training Error 2.623, Validation Error 2.619, Validation Accuracy 0.000
# Epoch 0, Training Error 2.613, Validation Error 2.617, Validation Accuracy 0.000
# Epoch 0, Training Error 2.621, Validation Error 2.616, Validation Accuracy 0.000
# Epoch 0, Training Error 2.624, Validation Error 2.614, Validation Accuracy 0.000
# Epoch 0, Training Error 2.626, Validation Error 2.613, Validation Accuracy 0.000
# Epoch 0, Training Error 2.618, Validation Error 2.611, Validation Accuracy 0.000
# Epoch 0, Training Error 2.622, Validation Error 2.610, Validation Accuracy 0.000
# Epoch 0, Training Error 2.597, Validation Error 2.608, Validation Accuracy 0.000
# Epoch 0, Training Error 2.594, Validation Error 2.607, Validation Accuracy 0.000
# Epoch 0, Training Error 2.594, Validation Error 2.605, Validation Accuracy 0.000
# Epoch 0, Training Error 2.601, Validation Error 2.604, Validation Accuracy 0.000
# Epoch 0, Training Error 2.596, Validation Error 2.602, Validation Accuracy 0.000
# Epoch 0, Training Error 2.595, Validation Error 2.601, Validation Accuracy 0.000
# Epoch 0, Training Error 2.600, Validation Error 2.599, Validation Accuracy 0.000
# Epoch 0, Training Error 2.583, Validation Error 2.598, Validation Accuracy 0.000
# Epoch 0, Training Error 2.595, Validation Error 2.596, Validation Accuracy 0.000
# Epoch 0, Training Error 2.596, Validation Error 2.595, Validation Accuracy 0.000
# Epoch 0, Training Error 2.618, Validation Error 2.593, Validation Accuracy 0.000
# Epoch 0, Training Error 2.596, Validation Error 2.592, Validation Accuracy 0.000
# Epoch 0, Training Error 2.591, Validation Error 2.590, Validation Accuracy 0.000
# Epoch 0, Training Error 2.580, Validation Error 2.589, Validation Accuracy 0.000
# Epoch 0, Training Error 2.604, Validation Error 2.587, Validation Accuracy 0.000
# Epoch 0, Training Error 2.591, Validation Error 2.586, Validation Accuracy 0.000
# Epoch 0, Training Error 2.582, Validation Error 2.584, Validation Accuracy 0.000
# Epoch 0, Training Error 2.583, Validation Error 2.583, Validation Accuracy 0.000
# Epoch 0, Training Error 2.583, Validation Error 2.581, Validation Accuracy 0.000
# Epoch 0, Training Error 2.582, Validation Error 2.580, Validation Accuracy 0.000
# Epoch 0, Training Error 2.580, Validation Error 2.578, Validation Accuracy 0.000
# Epoch 0, Training Error 2.574, Validation Error 2.577, Validation Accuracy 0.000
# Epoch 0, Training Error 2.579, Validation Error 2.575, Validation Accuracy 0.000
# Epoch 0, Training Error 2.556, Validation Error 2.574, Validation Accuracy 0.000
# Epoch 0, Training Error 2.585, Validation Error 2.572, Validation Accuracy 0.000
# Epoch 0, Training Error 2.558, Validation Error 2.571, Validation Accuracy 0.000
# Epoch 0, Training Error 2.562, Validation Error 2.569, Validation Accuracy 0.000
# Epoch 0, Training Error 2.566, Validation Error 2.568, Validation Accuracy 0.000
# Epoch 0, Training Error 2.558, Validation Error 2.566, Validation Accuracy 0.000
# Epoch 0, Training Error 2.557, Validation Error 2.565, Validation Accuracy 0.000
# Epoch 0, Training Error 2.566, Validation Error 2.563, Validation Accuracy 0.000
# Epoch 0, Training Error 2.559, Validation Error 2.562, Validation Accuracy 0.000
# Epoch 0, Training Error 2.539, Validation Error 2.560, Validation Accuracy 0.000
# Epoch 0, Training Error 2.554, Validation Error 2.559, Validation Accuracy 0.000
# Epoch 0, Training Error 2.554, Validation Error 2.557, Validation Accuracy 0.000
# Epoch 0, Training Error 2.555, Validation Error 2.556, Validation Accuracy 0.000
# Epoch 0, Training Error 2.544, Validation Error 2.555, Validation Accuracy 0.000
# Epoch 0, Training Error 2.557, Validation Error 2.553, Validation Accuracy 0.000
# Epoch 0, Training Error 2.558, Validation Error 2.552, Validation Accuracy 0.000
# Epoch 0, Training Error 2.537, Validation Error 2.550, Validation Accuracy 0.000
# Epoch 0, Training Error 2.554, Validation Error 2.549, Validation Accuracy 0.000
# Epoch 0, Training Error 2.551, Validation Error 2.547, Validation Accuracy 0.000
# Epoch 0, Training Error 2.538, Validation Error 2.546, Validation Accuracy 0.000
# Epoch 0, Training Error 2.539, Validation Error 2.544, Validation Accuracy 0.000
# Epoch 0, Training Error 2.551, Validation Error 2.543, Validation Accuracy 0.000
# Epoch 0, Training Error 2.545, Validation Error 2.541, Validation Accuracy 0.000
# Epoch 0, Training Error 2.520, Validation Error 2.540, Validation Accuracy 0.000
# Epoch 0, Training Error 2.556, Validation Error 2.538, Validation Accuracy 0.000
# Epoch 0, Training Error 2.538, Validation Error 2.537, Validation Accuracy 0.000
# Epoch 0, Training Error 2.546, Validation Error 2.536, Validation Accuracy 0.000
# Epoch 0, Training Error 2.525, Validation Error 2.534, Validation Accuracy 0.000
# Epoch 0, Training Error 2.535, Validation Error 2.533, Validation Accuracy 0.000
# Epoch 0, Training Error 2.534, Validation Error 2.531, Validation Accuracy 0.000
# Epoch 0, Training Error 2.526, Validation Error 2.530, Validation Accuracy 0.000
# Epoch 0, Training Error 2.536, Validation Error 2.528, Validation Accuracy 0.000
# Epoch 0, Training Error 2.523, Validation Error 2.527, Validation Accuracy 0.000
# Epoch 0, Training Error 2.523, Validation Error 2.525, Validation Accuracy 0.000
# Epoch 0, Training Error 2.517, Validation Error 2.524, Validation Accuracy 0.000
# Epoch 0, Training Error 2.510, Validation Error 2.523, Validation Accuracy 0.000
# Epoch 0, Training Error 2.518, Validation Error 2.521, Validation Accuracy 0.000
# Epoch 0, Training Error 2.526, Validation Error 2.520, Validation Accuracy 0.000
# Epoch 0, Training Error 2.502, Validation Error 2.518, Validation Accuracy 0.000
# Epoch 0, Training Error 2.534, Validation Error 2.517, Validation Accuracy 0.000
# Epoch 0, Training Error 2.524, Validation Error 2.515, Validation Accuracy 0.000
# Epoch 0, Training Error 2.522, Validation Error 2.514, Validation Accuracy 0.000
# Epoch 0, Training Error 2.507, Validation Error 2.513, Validation Accuracy 0.000
# Epoch 0, Training Error 2.524, Validation Error 2.511, Validation Accuracy 0.000
# Epoch 0, Training Error 2.522, Validation Error 2.510, Validation Accuracy 0.000
# Epoch 0, Training Error 2.500, Validation Error 2.508, Validation Accuracy 0.000
# Epoch 0, Training Error 2.520, Validation Error 2.507, Validation Accuracy 0.000
# Epoch 0, Training Error 2.522, Validation Error 2.506, Validation Accuracy 0.000
# Epoch 1, Training Error 2.494, Validation Error 2.505, Validation Accuracy 0.000
# Epoch 1, Training Error 2.505, Validation Error 2.504, Validation Accuracy 0.000
# Epoch 1, Training Error 2.514, Validation Error 2.502, Validation Accuracy 0.000
# Epoch 1, Training Error 2.510, Validation Error 2.501, Validation Accuracy 0.000
# Epoch 1, Training Error 2.497, Validation Error 2.499, Validation Accuracy 0.000
# Epoch 1, Training Error 2.504, Validation Error 2.498, Validation Accuracy 0.000
# Epoch 1, Training Error 2.502, Validation Error 2.497, Validation Accuracy 0.000
# Epoch 1, Training Error 2.505, Validation Error 2.495, Validation Accuracy 0.000
# Epoch 1, Training Error 2.499, Validation Error 2.494, Validation Accuracy 0.000
# Epoch 1, Training Error 2.473, Validation Error 2.492, Validation Accuracy 0.000
# Epoch 1, Training Error 2.492, Validation Error 2.491, Validation Accuracy 0.000
# Epoch 1, Training Error 2.493, Validation Error 2.489, Validation Accuracy 0.000
# Epoch 1, Training Error 2.500, Validation Error 2.488, Validation Accuracy 0.000
# Epoch 1, Training Error 2.484, Validation Error 2.487, Validation Accuracy 0.000
# Epoch 1, Training Error 2.479, Validation Error 2.485, Validation Accuracy 0.000
# Epoch 1, Training Error 2.463, Validation Error 2.484, Validation Accuracy 0.000
# Epoch 1, Training Error 2.496, Validation Error 2.482, Validation Accuracy 0.000
# Epoch 1, Training Error 2.482, Validation Error 2.481, Validation Accuracy 0.000
# Epoch 1, Training Error 2.495, Validation Error 2.480, Validation Accuracy 0.000
# Epoch 1, Training Error 2.476, Validation Error 2.478, Validation Accuracy 0.000
# Epoch 1, Training Error 2.475, Validation Error 2.477, Validation Accuracy 0.000
# Epoch 1, Training Error 2.481, Validation Error 2.475, Validation Accuracy 0.000
# Epoch 1, Training Error 2.461, Validation Error 2.474, Validation Accuracy 0.000
# Epoch 1, Training Error 2.473, Validation Error 2.473, Validation Accuracy 0.000
# Epoch 1, Training Error 2.479, Validation Error 2.471, Validation Accuracy 0.000
# Epoch 1, Training Error 2.471, Validation Error 2.470, Validation Accuracy 0.000
# Epoch 1, Training Error 2.466, Validation Error 2.468, Validation Accuracy 0.000
# Epoch 1, Training Error 2.465, Validation Error 2.467, Validation Accuracy 0.000
# Epoch 1, Training Error 2.469, Validation Error 2.466, Validation Accuracy 0.000
# Epoch 1, Training Error 2.459, Validation Error 2.464, Validation Accuracy 0.000
# Epoch 1, Training Error 2.475, Validation Error 2.463, Validation Accuracy 0.000
# Epoch 1, Training Error 2.457, Validation Error 2.462, Validation Accuracy 0.000
# Epoch 1, Training Error 2.457, Validation Error 2.460, Validation Accuracy 0.000
# Epoch 1, Training Error 2.455, Validation Error 2.459, Validation Accuracy 0.000
# Epoch 1, Training Error 2.464, Validation Error 2.457, Validation Accuracy 0.000
# Epoch 1, Training Error 2.457, Validation Error 2.456, Validation Accuracy 0.000
# Epoch 1, Training Error 2.462, Validation Error 2.455, Validation Accuracy 0.000
# Epoch 1, Training Error 2.449, Validation Error 2.453, Validation Accuracy 0.000
# Epoch 1, Training Error 2.451, Validation Error 2.452, Validation Accuracy 0.000
# Epoch 1, Training Error 2.450, Validation Error 2.451, Validation Accuracy 0.000
# Epoch 1, Training Error 2.462, Validation Error 2.449, Validation Accuracy 0.000
# Epoch 1, Training Error 2.441, Validation Error 2.448, Validation Accuracy 0.000
# Epoch 1, Training Error 2.442, Validation Error 2.446, Validation Accuracy 0.000
# Epoch 1, Training Error 2.434, Validation Error 2.445, Validation Accuracy 0.000
# Epoch 1, Training Error 2.445, Validation Error 2.444, Validation Accuracy 0.000
# Epoch 1, Training Error 2.442, Validation Error 2.442, Validation Accuracy 0.000
# Epoch 1, Training Error 2.440, Validation Error 2.441, Validation Accuracy 0.000
# Epoch 1, Training Error 2.446, Validation Error 2.440, Validation Accuracy 0.000
# Epoch 1, Training Error 2.453, Validation Error 2.438, Validation Accuracy 0.000
# Epoch 1, Training Error 2.433, Validation Error 2.437, Validation Accuracy 0.000
# Epoch 1, Training Error 2.435, Validation Error 2.436, Validation Accuracy 0.000
# Epoch 1, Training Error 2.437, Validation Error 2.434, Validation Accuracy 0.000
# Epoch 1, Training Error 2.432, Validation Error 2.433, Validation Accuracy 0.000
# Epoch 1, Training Error 2.419, Validation Error 2.431, Validation Accuracy 0.000
# Epoch 1, Training Error 2.440, Validation Error 2.430, Validation Accuracy 0.000
# Epoch 1, Training Error 2.410, Validation Error 2.429, Validation Accuracy 0.000
# Epoch 1, Training Error 2.432, Validation Error 2.427, Validation Accuracy 0.000
# Epoch 1, Training Error 2.433, Validation Error 2.426, Validation Accuracy 0.000
# Epoch 1, Training Error 2.431, Validation Error 2.425, Validation Accuracy 0.000
# Epoch 1, Training Error 2.436, Validation Error 2.423, Validation Accuracy 0.000
# Epoch 1, Training Error 2.426, Validation Error 2.422, Validation Accuracy 0.000
# Epoch 1, Training Error 2.407, Validation Error 2.421, Validation Accuracy 0.000
# Epoch 1, Training Error 2.421, Validation Error 2.419, Validation Accuracy 0.000
# Epoch 1, Training Error 2.420, Validation Error 2.418, Validation Accuracy 0.000
# Epoch 1, Training Error 2.401, Validation Error 2.417, Validation Accuracy 0.000
# Epoch 1, Training Error 2.411, Validation Error 2.415, Validation Accuracy 0.000
# Epoch 1, Training Error 2.412, Validation Error 2.414, Validation Accuracy 0.000
# Epoch 1, Training Error 2.416, Validation Error 2.413, Validation Accuracy 0.000
# Epoch 1, Training Error 2.393, Validation Error 2.411, Validation Accuracy 0.000
# Epoch 1, Training Error 2.398, Validation Error 2.410, Validation Accuracy 0.000
# Epoch 1, Training Error 2.403, Validation Error 2.409, Validation Accuracy 0.000
# Epoch 1, Training Error 2.404, Validation Error 2.407, Validation Accuracy 0.000
# Epoch 1, Training Error 2.407, Validation Error 2.406, Validation Accuracy 0.000
# Epoch 1, Training Error 2.407, Validation Error 2.405, Validation Accuracy 0.000
# Epoch 1, Training Error 2.420, Validation Error 2.403, Validation Accuracy 0.000
# Epoch 1, Training Error 2.388, Validation Error 2.402, Validation Accuracy 0.000
# Epoch 1, Training Error 2.394, Validation Error 2.401, Validation Accuracy 0.000
# Epoch 1, Training Error 2.376, Validation Error 2.399, Validation Accuracy 0.000
# Epoch 1, Training Error 2.384, Validation Error 2.398, Validation Accuracy 0.000
# Epoch 1, Training Error 2.400, Validation Error 2.397, Validation Accuracy 0.000
# Epoch 1, Training Error 2.393, Validation Error 2.395, Validation Accuracy 0.000
# Epoch 1, Training Error 2.399, Validation Error 2.394, Validation Accuracy 0.000
# Epoch 1, Training Error 2.401, Validation Error 2.393, Validation Accuracy 0.000
# Epoch 1, Training Error 2.402, Validation Error 2.391, Validation Accuracy 0.000
# Epoch 1, Training Error 2.397, Validation Error 2.390, Validation Accuracy 0.000
# Epoch 1, Training Error 2.400, Validation Error 2.389, Validation Accuracy 0.000
# Epoch 1, Training Error 2.377, Validation Error 2.388, Validation Accuracy 0.000
# Epoch 1, Training Error 2.376, Validation Error 2.386, Validation Accuracy 0.000
# Epoch 1, Training Error 2.376, Validation Error 2.385, Validation Accuracy 0.000
# Epoch 1, Training Error 2.382, Validation Error 2.384, Validation Accuracy 0.000
# Epoch 1, Training Error 2.376, Validation Error 2.382, Validation Accuracy 0.000
# Epoch 1, Training Error 2.377, Validation Error 2.381, Validation Accuracy 0.000
# Epoch 1, Training Error 2.379, Validation Error 2.380, Validation Accuracy 0.000
# Epoch 1, Training Error 2.365, Validation Error 2.378, Validation Accuracy 0.000
# Epoch 1, Training Error 2.376, Validation Error 2.377, Validation Accuracy 0.000
# Epoch 1, Training Error 2.376, Validation Error 2.376, Validation Accuracy 0.000
# Epoch 1, Training Error 2.396, Validation Error 2.374, Validation Accuracy 0.000
# Epoch 1, Training Error 2.379, Validation Error 2.373, Validation Accuracy 0.000
# Epoch 1, Training Error 2.373, Validation Error 2.372, Validation Accuracy 0.000
# Epoch 1, Training Error 2.364, Validation Error 2.371, Validation Accuracy 0.000
# Epoch 1, Training Error 2.384, Validation Error 2.369, Validation Accuracy 0.000
# Epoch 1, Training Error 2.370, Validation Error 2.368, Validation Accuracy 0.000
# Epoch 1, Training Error 2.365, Validation Error 2.367, Validation Accuracy 0.000
# Epoch 1, Training Error 2.366, Validation Error 2.365, Validation Accuracy 0.000
# Epoch 1, Training Error 2.365, Validation Error 2.364, Validation Accuracy 0.000
# Epoch 1, Training Error 2.365, Validation Error 2.363, Validation Accuracy 0.000
# Epoch 1, Training Error 2.363, Validation Error 2.362, Validation Accuracy 0.000
# Epoch 1, Training Error 2.357, Validation Error 2.360, Validation Accuracy 0.000
# Epoch 1, Training Error 2.363, Validation Error 2.359, Validation Accuracy 0.000
# Epoch 1, Training Error 2.341, Validation Error 2.358, Validation Accuracy 0.000
# Epoch 1, Training Error 2.369, Validation Error 2.356, Validation Accuracy 0.000
# Epoch 1, Training Error 2.343, Validation Error 2.355, Validation Accuracy 0.000
# Epoch 1, Training Error 2.347, Validation Error 2.354, Validation Accuracy 0.000
# Epoch 1, Training Error 2.351, Validation Error 2.353, Validation Accuracy 0.000
# Epoch 1, Training Error 2.345, Validation Error 2.351, Validation Accuracy 0.000
# Epoch 1, Training Error 2.344, Validation Error 2.350, Validation Accuracy 0.000
# Epoch 1, Training Error 2.350, Validation Error 2.349, Validation Accuracy 0.000
# Epoch 1, Training Error 2.345, Validation Error 2.347, Validation Accuracy 0.000
# Epoch 1, Training Error 2.327, Validation Error 2.346, Validation Accuracy 0.000
# Epoch 1, Training Error 2.340, Validation Error 2.345, Validation Accuracy 0.000
# Epoch 1, Training Error 2.341, Validation Error 2.344, Validation Accuracy 0.000
# Epoch 1, Training Error 2.342, Validation Error 2.342, Validation Accuracy 0.000
# Epoch 1, Training Error 2.329, Validation Error 2.341, Validation Accuracy 0.000
# Epoch 1, Training Error 2.342, Validation Error 2.340, Validation Accuracy 0.000
# Epoch 1, Training Error 2.344, Validation Error 2.339, Validation Accuracy 0.000
# Epoch 1, Training Error 2.323, Validation Error 2.337, Validation Accuracy 0.000
# Epoch 1, Training Error 2.342, Validation Error 2.336, Validation Accuracy 0.000
# Epoch 1, Training Error 2.337, Validation Error 2.335, Validation Accuracy 0.000
# Epoch 1, Training Error 2.325, Validation Error 2.334, Validation Accuracy 0.000
# Epoch 1, Training Error 2.328, Validation Error 2.332, Validation Accuracy 0.000
# Epoch 1, Training Error 2.336, Validation Error 2.331, Validation Accuracy 0.000
# Epoch 1, Training Error 2.331, Validation Error 2.330, Validation Accuracy 0.000
# Epoch 1, Training Error 2.310, Validation Error 2.328, Validation Accuracy 0.000
# Epoch 1, Training Error 2.343, Validation Error 2.327, Validation Accuracy 0.000
# Epoch 1, Training Error 2.328, Validation Error 2.326, Validation Accuracy 0.000
# Epoch 1, Training Error 2.334, Validation Error 2.325, Validation Accuracy 0.000
# Epoch 1, Training Error 2.314, Validation Error 2.323, Validation Accuracy 0.000
# Epoch 1, Training Error 2.326, Validation Error 2.322, Validation Accuracy 0.000
# Epoch 1, Training Error 2.322, Validation Error 2.321, Validation Accuracy 0.000
# Epoch 1, Training Error 2.314, Validation Error 2.320, Validation Accuracy 0.000
# Epoch 1, Training Error 2.325, Validation Error 2.318, Validation Accuracy 0.000
# Epoch 1, Training Error 2.313, Validation Error 2.317, Validation Accuracy 0.000
# Epoch 1, Training Error 2.312, Validation Error 2.316, Validation Accuracy 0.000
# Epoch 1, Training Error 2.309, Validation Error 2.315, Validation Accuracy 0.000
# Epoch 1, Training Error 2.300, Validation Error 2.313, Validation Accuracy 0.000
# Epoch 1, Training Error 2.309, Validation Error 2.312, Validation Accuracy 0.000
# Epoch 1, Training Error 2.317, Validation Error 2.311, Validation Accuracy 0.000
# Epoch 1, Training Error 2.295, Validation Error 2.310, Validation Accuracy 0.000
# Epoch 1, Training Error 2.325, Validation Error 2.308, Validation Accuracy 0.000
# Epoch 1, Training Error 2.315, Validation Error 2.307, Validation Accuracy 0.000
# Epoch 1, Training Error 2.314, Validation Error 2.306, Validation Accuracy 0.000
# Epoch 1, Training Error 2.300, Validation Error 2.305, Validation Accuracy 0.000
# Epoch 1, Training Error 2.315, Validation Error 2.304, Validation Accuracy 0.000
# Epoch 1, Training Error 2.314, Validation Error 2.302, Validation Accuracy 0.000
# Epoch 1, Training Error 2.294, Validation Error 2.301, Validation Accuracy 0.000
# Epoch 1, Training Error 2.310, Validation Error 2.300, Validation Accuracy 0.000
# Epoch 1, Training Error 2.314, Validation Error 2.300, Validation Accuracy 0.000
# Epoch 2, Training Error 2.288, Validation Error 2.298, Validation Accuracy 0.000
# Epoch 2, Training Error 2.300, Validation Error 2.297, Validation Accuracy 0.000
# Epoch 2, Training Error 2.306, Validation Error 2.296, Validation Accuracy 0.000
# Epoch 2, Training Error 2.302, Validation Error 2.295, Validation Accuracy 0.000
# Epoch 2, Training Error 2.291, Validation Error 2.293, Validation Accuracy 0.000
# Epoch 2, Training Error 2.298, Validation Error 2.292, Validation Accuracy 0.000
# Epoch 2, Training Error 2.295, Validation Error 2.291, Validation Accuracy 0.000
# Epoch 2, Training Error 2.298, Validation Error 2.290, Validation Accuracy 0.000
# Epoch 2, Training Error 2.293, Validation Error 2.288, Validation Accuracy 0.000
# Epoch 2, Training Error 2.269, Validation Error 2.287, Validation Accuracy 0.000
# Epoch 2, Training Error 2.285, Validation Error 2.286, Validation Accuracy 0.000
# Epoch 2, Training Error 2.288, Validation Error 2.285, Validation Accuracy 0.000
# Epoch 2, Training Error 2.293, Validation Error 2.284, Validation Accuracy 0.000
# Epoch 2, Training Error 2.281, Validation Error 2.282, Validation Accuracy 0.000
# Epoch 2, Training Error 2.276, Validation Error 2.281, Validation Accuracy 0.000
# Epoch 2, Training Error 2.262, Validation Error 2.280, Validation Accuracy 0.000
# Epoch 2, Training Error 2.290, Validation Error 2.279, Validation Accuracy 0.000
# Epoch 2, Training Error 2.278, Validation Error 2.278, Validation Accuracy 0.000
# Epoch 2, Training Error 2.290, Validation Error 2.276, Validation Accuracy 0.000
# Epoch 2, Training Error 2.273, Validation Error 2.275, Validation Accuracy 0.000
# Epoch 2, Training Error 2.271, Validation Error 2.274, Validation Accuracy 0.000
# Epoch 2, Training Error 2.278, Validation Error 2.273, Validation Accuracy 0.000
# Epoch 2, Training Error 2.260, Validation Error 2.272, Validation Accuracy 0.000
# Epoch 2, Training Error 2.270, Validation Error 2.270, Validation Accuracy 0.000
# Epoch 2, Training Error 2.275, Validation Error 2.269, Validation Accuracy 0.000
# Epoch 2, Training Error 2.269, Validation Error 2.268, Validation Accuracy 0.000
# Epoch 2, Training Error 2.265, Validation Error 2.267, Validation Accuracy 0.000
# Epoch 2, Training Error 2.266, Validation Error 2.266, Validation Accuracy 0.000
# Epoch 2, Training Error 2.267, Validation Error 2.264, Validation Accuracy 0.000
# Epoch 2, Training Error 2.258, Validation Error 2.263, Validation Accuracy 0.000
# Epoch 2, Training Error 2.271, Validation Error 2.262, Validation Accuracy 0.000
# Epoch 2, Training Error 2.256, Validation Error 2.261, Validation Accuracy 0.000
# Epoch 2, Training Error 2.256, Validation Error 2.260, Validation Accuracy 0.000
# Epoch 2, Training Error 2.254, Validation Error 2.258, Validation Accuracy 0.000
# Epoch 2, Training Error 2.263, Validation Error 2.257, Validation Accuracy 0.000
# Epoch 2, Training Error 2.258, Validation Error 2.256, Validation Accuracy 0.000
# Epoch 2, Training Error 2.261, Validation Error 2.255, Validation Accuracy 0.000
# Epoch 2, Training Error 2.250, Validation Error 2.254, Validation Accuracy 0.000
# Epoch 2, Training Error 2.251, Validation Error 2.252, Validation Accuracy 0.000
# Epoch 2, Training Error 2.252, Validation Error 2.251, Validation Accuracy 0.000
# Epoch 2, Training Error 2.261, Validation Error 2.250, Validation Accuracy 0.000
# Epoch 2, Training Error 2.243, Validation Error 2.249, Validation Accuracy 0.000
# Epoch 2, Training Error 2.243, Validation Error 2.248, Validation Accuracy 0.000
# Epoch 2, Training Error 2.235, Validation Error 2.246, Validation Accuracy 0.000
# Epoch 2, Training Error 2.246, Validation Error 2.245, Validation Accuracy 0.000
# Epoch 2, Training Error 2.246, Validation Error 2.244, Validation Accuracy 0.000
# Epoch 2, Training Error 2.242, Validation Error 2.243, Validation Accuracy 0.000
# Epoch 2, Training Error 2.247, Validation Error 2.242, Validation Accuracy 0.000
# Epoch 2, Training Error 2.253, Validation Error 2.241, Validation Accuracy 0.000
# Epoch 2, Training Error 2.236, Validation Error 2.239, Validation Accuracy 0.000
# Epoch 2, Training Error 2.237, Validation Error 2.238, Validation Accuracy 0.000
# Epoch 2, Training Error 2.239, Validation Error 2.237, Validation Accuracy 0.000
# Epoch 2, Training Error 2.235, Validation Error 2.236, Validation Accuracy 0.000
# Epoch 2, Training Error 2.224, Validation Error 2.235, Validation Accuracy 0.000
# Epoch 2, Training Error 2.244, Validation Error 2.234, Validation Accuracy 0.000
# Epoch 2, Training Error 2.216, Validation Error 2.232, Validation Accuracy 0.000
# Epoch 2, Training Error 2.235, Validation Error 2.231, Validation Accuracy 0.000
# Epoch 2, Training Error 2.237, Validation Error 2.230, Validation Accuracy 0.000
# Epoch 2, Training Error 2.234, Validation Error 2.229, Validation Accuracy 0.000
# Epoch 2, Training Error 2.239, Validation Error 2.228, Validation Accuracy 0.000
# Epoch 2, Training Error 2.230, Validation Error 2.227, Validation Accuracy 0.000
# Epoch 2, Training Error 2.214, Validation Error 2.225, Validation Accuracy 0.000
# Epoch 2, Training Error 2.226, Validation Error 2.224, Validation Accuracy 0.000
# Epoch 2, Training Error 2.224, Validation Error 2.223, Validation Accuracy 0.000
# Epoch 2, Training Error 2.207, Validation Error 2.222, Validation Accuracy 0.000
# Epoch 2, Training Error 2.218, Validation Error 2.221, Validation Accuracy 0.000
# Epoch 2, Training Error 2.219, Validation Error 2.220, Validation Accuracy 0.000
# Epoch 2, Training Error 2.221, Validation Error 2.218, Validation Accuracy 0.000
# Epoch 2, Training Error 2.200, Validation Error 2.217, Validation Accuracy 0.000
# Epoch 2, Training Error 2.203, Validation Error 2.216, Validation Accuracy 0.000
# Epoch 2, Training Error 2.209, Validation Error 2.215, Validation Accuracy 0.000
# Epoch 2, Training Error 2.210, Validation Error 2.214, Validation Accuracy 0.000
# Epoch 2, Training Error 2.213, Validation Error 2.213, Validation Accuracy 0.000
# Epoch 2, Training Error 2.214, Validation Error 2.212, Validation Accuracy 0.000
# Epoch 2, Training Error 2.226, Validation Error 2.210, Validation Accuracy 0.000
# Epoch 2, Training Error 2.196, Validation Error 2.209, Validation Accuracy 0.000
# Epoch 2, Training Error 2.202, Validation Error 2.208, Validation Accuracy 0.000
# Epoch 2, Training Error 2.188, Validation Error 2.207, Validation Accuracy 0.000
# Epoch 2, Training Error 2.192, Validation Error 2.206, Validation Accuracy 0.000
# Epoch 2, Training Error 2.206, Validation Error 2.205, Validation Accuracy 0.000
# Epoch 2, Training Error 2.202, Validation Error 2.204, Validation Accuracy 0.000
# Epoch 2, Training Error 2.207, Validation Error 2.202, Validation Accuracy 0.000
# Epoch 2, Training Error 2.209, Validation Error 2.201, Validation Accuracy 0.000
# Epoch 2, Training Error 2.208, Validation Error 2.200, Validation Accuracy 0.000
# Epoch 2, Training Error 2.206, Validation Error 2.199, Validation Accuracy 0.000
# Epoch 2, Training Error 2.208, Validation Error 2.198, Validation Accuracy 0.000
# Epoch 2, Training Error 2.188, Validation Error 2.197, Validation Accuracy 0.000
# Epoch 2, Training Error 2.187, Validation Error 2.196, Validation Accuracy 0.000
# Epoch 2, Training Error 2.187, Validation Error 2.195, Validation Accuracy 0.000
# Epoch 2, Training Error 2.192, Validation Error 2.193, Validation Accuracy 0.000
# Epoch 2, Training Error 2.187, Validation Error 2.192, Validation Accuracy 0.000
# Epoch 2, Training Error 2.188, Validation Error 2.191, Validation Accuracy 0.000
# Epoch 2, Training Error 2.188, Validation Error 2.190, Validation Accuracy 0.000
# Epoch 2, Training Error 2.177, Validation Error 2.189, Validation Accuracy 0.000
# Epoch 2, Training Error 2.188, Validation Error 2.188, Validation Accuracy 0.000
# Epoch 2, Training Error 2.186, Validation Error 2.187, Validation Accuracy 0.000
# Epoch 2, Training Error 2.205, Validation Error 2.186, Validation Accuracy 0.000
# Epoch 2, Training Error 2.191, Validation Error 2.184, Validation Accuracy 0.000
# Epoch 2, Training Error 2.185, Validation Error 2.183, Validation Accuracy 0.000
# Epoch 2, Training Error 2.177, Validation Error 2.182, Validation Accuracy 0.000
# Epoch 2, Training Error 2.194, Validation Error 2.181, Validation Accuracy 0.000
# Epoch 2, Training Error 2.179, Validation Error 2.180, Validation Accuracy 0.000
# Epoch 2, Training Error 2.177, Validation Error 2.179, Validation Accuracy 0.000
# Epoch 2, Training Error 2.179, Validation Error 2.178, Validation Accuracy 0.000
# Epoch 2, Training Error 2.177, Validation Error 2.177, Validation Accuracy 0.000
# Epoch 2, Training Error 2.178, Validation Error 2.175, Validation Accuracy 0.000
# Epoch 2, Training Error 2.176, Validation Error 2.174, Validation Accuracy 0.000
# Epoch 2, Training Error 2.169, Validation Error 2.173, Validation Accuracy 0.000
# Epoch 2, Training Error 2.175, Validation Error 2.172, Validation Accuracy 0.000
# Epoch 2, Training Error 2.156, Validation Error 2.171, Validation Accuracy 0.000
# Epoch 2, Training Error 2.182, Validation Error 2.170, Validation Accuracy 0.000
# Epoch 2, Training Error 2.159, Validation Error 2.169, Validation Accuracy 0.000
# Epoch 2, Training Error 2.162, Validation Error 2.168, Validation Accuracy 0.000
# Epoch 2, Training Error 2.165, Validation Error 2.167, Validation Accuracy 0.000
# Epoch 2, Training Error 2.161, Validation Error 2.166, Validation Accuracy 0.000
# Epoch 2, Training Error 2.159, Validation Error 2.164, Validation Accuracy 0.000
# Epoch 2, Training Error 2.164, Validation Error 2.163, Validation Accuracy 0.000
# Epoch 2, Training Error 2.160, Validation Error 2.162, Validation Accuracy 0.000
# Epoch 2, Training Error 2.144, Validation Error 2.161, Validation Accuracy 0.000
# Epoch 2, Training Error 2.155, Validation Error 2.160, Validation Accuracy 0.000
# Epoch 2, Training Error 2.158, Validation Error 2.159, Validation Accuracy 0.000
# Epoch 2, Training Error 2.158, Validation Error 2.158, Validation Accuracy 0.000
# Epoch 2, Training Error 2.144, Validation Error 2.157, Validation Accuracy 0.000
# Epoch 2, Training Error 2.157, Validation Error 2.156, Validation Accuracy 0.000
# Epoch 2, Training Error 2.159, Validation Error 2.155, Validation Accuracy 0.000
# Epoch 2, Training Error 2.140, Validation Error 2.153, Validation Accuracy 0.000
# Epoch 2, Training Error 2.158, Validation Error 2.152, Validation Accuracy 0.000
# Epoch 2, Training Error 2.152, Validation Error 2.151, Validation Accuracy 0.000
# Epoch 2, Training Error 2.141, Validation Error 2.150, Validation Accuracy 0.000
# Epoch 2, Training Error 2.146, Validation Error 2.149, Validation Accuracy 0.000
# Epoch 2, Training Error 2.150, Validation Error 2.148, Validation Accuracy 0.000
# Epoch 2, Training Error 2.147, Validation Error 2.147, Validation Accuracy 0.000
# Epoch 2, Training Error 2.129, Validation Error 2.146, Validation Accuracy 0.000
# Epoch 2, Training Error 2.158, Validation Error 2.145, Validation Accuracy 0.000
# Epoch 2, Training Error 2.146, Validation Error 2.144, Validation Accuracy 0.000
# Epoch 2, Training Error 2.151, Validation Error 2.143, Validation Accuracy 0.000
# Epoch 2, Training Error 2.133, Validation Error 2.142, Validation Accuracy 0.000
# Epoch 2, Training Error 2.145, Validation Error 2.140, Validation Accuracy 0.000
# Epoch 2, Training Error 2.140, Validation Error 2.139, Validation Accuracy 0.000
# Epoch 2, Training Error 2.132, Validation Error 2.138, Validation Accuracy 0.000
# Epoch 2, Training Error 2.143, Validation Error 2.137, Validation Accuracy 0.000
# Epoch 2, Training Error 2.131, Validation Error 2.136, Validation Accuracy 0.000
# Epoch 2, Training Error 2.131, Validation Error 2.135, Validation Accuracy 0.000
# Epoch 2, Training Error 2.129, Validation Error 2.134, Validation Accuracy 0.000
# Epoch 2, Training Error 2.120, Validation Error 2.133, Validation Accuracy 0.000
# Epoch 2, Training Error 2.128, Validation Error 2.132, Validation Accuracy 0.000
# Epoch 2, Training Error 2.136, Validation Error 2.131, Validation Accuracy 0.000
# Epoch 2, Training Error 2.116, Validation Error 2.130, Validation Accuracy 0.000
# Epoch 2, Training Error 2.144, Validation Error 2.129, Validation Accuracy 0.000
# Epoch 2, Training Error 2.135, Validation Error 2.128, Validation Accuracy 0.000
# Epoch 2, Training Error 2.135, Validation Error 2.127, Validation Accuracy 0.000
# Epoch 2, Training Error 2.122, Validation Error 2.125, Validation Accuracy 0.000
# Epoch 2, Training Error 2.134, Validation Error 2.124, Validation Accuracy 0.000
# Epoch 2, Training Error 2.134, Validation Error 2.123, Validation Accuracy 0.000
# Epoch 2, Training Error 2.116, Validation Error 2.122, Validation Accuracy 0.000
# Epoch 2, Training Error 2.129, Validation Error 2.121, Validation Accuracy 0.000
# Epoch 2, Training Error 2.135, Validation Error 2.121, Validation Accuracy 0.000
# Epoch 3, Training Error 2.111, Validation Error 2.120, Validation Accuracy 0.000
# Epoch 3, Training Error 2.123, Validation Error 2.119, Validation Accuracy 0.000
# Epoch 3, Training Error 2.126, Validation Error 2.118, Validation Accuracy 0.000
# Epoch 3, Training Error 2.123, Validation Error 2.117, Validation Accuracy 0.000
# Epoch 3, Training Error 2.114, Validation Error 2.116, Validation Accuracy 0.000
# Epoch 3, Training Error 2.120, Validation Error 2.115, Validation Accuracy 0.000
# Epoch 3, Training Error 2.117, Validation Error 2.114, Validation Accuracy 0.000
# Epoch 3, Training Error 2.119, Validation Error 2.112, Validation Accuracy 0.000
# Epoch 3, Training Error 2.116, Validation Error 2.111, Validation Accuracy 0.000
# Epoch 3, Training Error 2.094, Validation Error 2.110, Validation Accuracy 0.000
# Epoch 3, Training Error 2.108, Validation Error 2.109, Validation Accuracy 0.000
# Epoch 3, Training Error 2.111, Validation Error 2.108, Validation Accuracy 0.000
# Epoch 3, Training Error 2.115, Validation Error 2.107, Validation Accuracy 0.000
# Epoch 3, Training Error 2.105, Validation Error 2.106, Validation Accuracy 0.000
# Epoch 3, Training Error 2.100, Validation Error 2.105, Validation Accuracy 0.000
# Epoch 3, Training Error 2.089, Validation Error 2.104, Validation Accuracy 0.000
# Epoch 3, Training Error 2.113, Validation Error 2.103, Validation Accuracy 0.000
# Epoch 3, Training Error 2.101, Validation Error 2.102, Validation Accuracy 0.000
# Epoch 3, Training Error 2.112, Validation Error 2.101, Validation Accuracy 0.000
# Epoch 3, Training Error 2.098, Validation Error 2.100, Validation Accuracy 0.000
# Epoch 3, Training Error 2.096, Validation Error 2.099, Validation Accuracy 0.000
# Epoch 3, Training Error 2.103, Validation Error 2.098, Validation Accuracy 0.000
# Epoch 3, Training Error 2.086, Validation Error 2.097, Validation Accuracy 0.000
# Epoch 3, Training Error 2.095, Validation Error 2.096, Validation Accuracy 0.000
# Epoch 3, Training Error 2.100, Validation Error 2.095, Validation Accuracy 0.000
# Epoch 3, Training Error 2.094, Validation Error 2.094, Validation Accuracy 0.000
# Epoch 3, Training Error 2.091, Validation Error 2.093, Validation Accuracy 0.000
# Epoch 3, Training Error 2.093, Validation Error 2.092, Validation Accuracy 0.000
# Epoch 3, Training Error 2.093, Validation Error 2.091, Validation Accuracy 0.000
# Epoch 3, Training Error 2.084, Validation Error 2.090, Validation Accuracy 0.000
# Epoch 3, Training Error 2.096, Validation Error 2.088, Validation Accuracy 0.000
# Epoch 3, Training Error 2.084, Validation Error 2.087, Validation Accuracy 0.000
# Epoch 3, Training Error 2.083, Validation Error 2.086, Validation Accuracy 0.000
# Epoch 3, Training Error 2.081, Validation Error 2.085, Validation Accuracy 0.000
# Epoch 3, Training Error 2.089, Validation Error 2.084, Validation Accuracy 0.000
# Epoch 3, Training Error 2.086, Validation Error 2.083, Validation Accuracy 0.000
# Epoch 3, Training Error 2.088, Validation Error 2.082, Validation Accuracy 0.000
# Epoch 3, Training Error 2.079, Validation Error 2.081, Validation Accuracy 0.000
# Epoch 3, Training Error 2.079, Validation Error 2.080, Validation Accuracy 0.000
# Epoch 3, Training Error 2.080, Validation Error 2.079, Validation Accuracy 0.000
# Epoch 3, Training Error 2.087, Validation Error 2.078, Validation Accuracy 0.000
# Epoch 3, Training Error 2.072, Validation Error 2.077, Validation Accuracy 0.000
# Epoch 3, Training Error 2.071, Validation Error 2.076, Validation Accuracy 0.000
# Epoch 3, Training Error 2.063, Validation Error 2.075, Validation Accuracy 0.000
# Epoch 3, Training Error 2.074, Validation Error 2.074, Validation Accuracy 0.000
# Epoch 3, Training Error 2.076, Validation Error 2.073, Validation Accuracy 0.000
# Epoch 3, Training Error 2.071, Validation Error 2.072, Validation Accuracy 0.000
# Epoch 3, Training Error 2.076, Validation Error 2.071, Validation Accuracy 0.000
# Epoch 3, Training Error 2.081, Validation Error 2.070, Validation Accuracy 0.000
# Epoch 3, Training Error 2.066, Validation Error 2.069, Validation Accuracy 0.000
# Epoch 3, Training Error 2.066, Validation Error 2.068, Validation Accuracy 0.000
# Epoch 3, Training Error 2.068, Validation Error 2.067, Validation Accuracy 0.000
# Epoch 3, Training Error 2.066, Validation Error 2.066, Validation Accuracy 0.000
# Epoch 3, Training Error 2.055, Validation Error 2.065, Validation Accuracy 0.000
# Epoch 3, Training Error 2.074, Validation Error 2.064, Validation Accuracy 0.000
# Epoch 3, Training Error 2.048, Validation Error 2.063, Validation Accuracy 0.000
# Epoch 3, Training Error 2.066, Validation Error 2.062, Validation Accuracy 0.000
# Epoch 3, Training Error 2.067, Validation Error 2.061, Validation Accuracy 0.000
# Epoch 3, Training Error 2.064, Validation Error 2.060, Validation Accuracy 0.000
# Epoch 3, Training Error 2.068, Validation Error 2.059, Validation Accuracy 0.000
# Epoch 3, Training Error 2.060, Validation Error 2.058, Validation Accuracy 0.000
# Epoch 3, Training Error 2.047, Validation Error 2.057, Validation Accuracy 0.000
# Epoch 3, Training Error 2.058, Validation Error 2.056, Validation Accuracy 0.000
# Epoch 3, Training Error 2.055, Validation Error 2.055, Validation Accuracy 0.000
# Epoch 3, Training Error 2.041, Validation Error 2.054, Validation Accuracy 0.000
# Epoch 3, Training Error 2.052, Validation Error 2.053, Validation Accuracy 0.000
# Epoch 3, Training Error 2.052, Validation Error 2.052, Validation Accuracy 0.000
# Epoch 3, Training Error 2.054, Validation Error 2.051, Validation Accuracy 0.000
# Epoch 3, Training Error 2.034, Validation Error 2.050, Validation Accuracy 0.000
# Epoch 3, Training Error 2.036, Validation Error 2.049, Validation Accuracy 0.000
# Epoch 3, Training Error 2.043, Validation Error 2.048, Validation Accuracy 0.000
# Epoch 3, Training Error 2.043, Validation Error 2.047, Validation Accuracy 0.000
# Epoch 3, Training Error 2.046, Validation Error 2.046, Validation Accuracy 0.000
# Epoch 3, Training Error 2.048, Validation Error 2.045, Validation Accuracy 0.000
# Epoch 3, Training Error 2.058, Validation Error 2.044, Validation Accuracy 0.000
# Epoch 3, Training Error 2.031, Validation Error 2.043, Validation Accuracy 0.000
# Epoch 3, Training Error 2.037, Validation Error 2.042, Validation Accuracy 0.000
# Epoch 3, Training Error 2.025, Validation Error 2.041, Validation Accuracy 0.000
# Epoch 3, Training Error 2.027, Validation Error 2.040, Validation Accuracy 0.000
# Epoch 3, Training Error 2.040, Validation Error 2.039, Validation Accuracy 0.000
# Epoch 3, Training Error 2.037, Validation Error 2.038, Validation Accuracy 0.000
# Epoch 3, Training Error 2.041, Validation Error 2.037, Validation Accuracy 0.000
# Epoch 3, Training Error 2.043, Validation Error 2.036, Validation Accuracy 0.000
# Epoch 3, Training Error 2.041, Validation Error 2.035, Validation Accuracy 0.000
# Epoch 3, Training Error 2.041, Validation Error 2.034, Validation Accuracy 0.000
# Epoch 3, Training Error 2.042, Validation Error 2.033, Validation Accuracy 0.000
# Epoch 3, Training Error 2.024, Validation Error 2.032, Validation Accuracy 0.000
# Epoch 3, Training Error 2.025, Validation Error 2.031, Validation Accuracy 0.000
# Epoch 3, Training Error 2.025, Validation Error 2.030, Validation Accuracy 0.000
# Epoch 3, Training Error 2.029, Validation Error 2.029, Validation Accuracy 0.000
# Epoch 3, Training Error 2.024, Validation Error 2.029, Validation Accuracy 0.000
# Epoch 3, Training Error 2.025, Validation Error 2.028, Validation Accuracy 0.000
# Epoch 3, Training Error 2.024, Validation Error 2.027, Validation Accuracy 0.000
# Epoch 3, Training Error 2.015, Validation Error 2.026, Validation Accuracy 0.000
# Epoch 3, Training Error 2.025, Validation Error 2.025, Validation Accuracy 0.000
# Epoch 3, Training Error 2.023, Validation Error 2.024, Validation Accuracy 0.000
# Epoch 3, Training Error 2.040, Validation Error 2.023, Validation Accuracy 0.000
# Epoch 3, Training Error 2.029, Validation Error 2.022, Validation Accuracy 0.000
# Epoch 3, Training Error 2.022, Validation Error 2.021, Validation Accuracy 0.000
# Epoch 3, Training Error 2.015, Validation Error 2.020, Validation Accuracy 0.000
# Epoch 3, Training Error 2.030, Validation Error 2.019, Validation Accuracy 0.000
# Epoch 3, Training Error 2.015, Validation Error 2.018, Validation Accuracy 0.000
# Epoch 3, Training Error 2.015, Validation Error 2.017, Validation Accuracy 0.000
# Epoch 3, Training Error 2.017, Validation Error 2.016, Validation Accuracy 0.000
# Epoch 3, Training Error 2.015, Validation Error 2.015, Validation Accuracy 0.000
# Epoch 3, Training Error 2.017, Validation Error 2.014, Validation Accuracy 0.000
# Epoch 3, Training Error 2.015, Validation Error 2.013, Validation Accuracy 0.000
# Epoch 3, Training Error 2.008, Validation Error 2.012, Validation Accuracy 0.000
# Epoch 3, Training Error 2.014, Validation Error 2.011, Validation Accuracy 0.000
# Epoch 3, Training Error 1.996, Validation Error 2.010, Validation Accuracy 0.000
# Epoch 3, Training Error 2.021, Validation Error 2.009, Validation Accuracy 0.000
# Epoch 3, Training Error 1.999, Validation Error 2.008, Validation Accuracy 0.000
# Epoch 3, Training Error 2.002, Validation Error 2.007, Validation Accuracy 0.000
# Epoch 3, Training Error 2.004, Validation Error 2.006, Validation Accuracy 0.000
# Epoch 3, Training Error 2.002, Validation Error 2.005, Validation Accuracy 0.000
# Epoch 3, Training Error 2.000, Validation Error 2.004, Validation Accuracy 0.000
# Epoch 3, Training Error 2.004, Validation Error 2.004, Validation Accuracy 0.000
# Epoch 3, Training Error 2.001, Validation Error 2.003, Validation Accuracy 0.000
# Epoch 3, Training Error 1.987, Validation Error 2.002, Validation Accuracy 0.000
# Epoch 3, Training Error 1.996, Validation Error 2.001, Validation Accuracy 0.000
# Epoch 3, Training Error 1.999, Validation Error 2.000, Validation Accuracy 0.000
# ...
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.913, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.913, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.913, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.913, Validation Error 0.915, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.916, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 56, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.916, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.913, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.916, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.914, Validation Error 0.914, Validation Accuracy 0.000
# Epoch 57, Training Error 0.915, Validation Error 0.914, Validation Accuracy 0.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1af3cf155910> in <module>()
# ----> 1 network.run(train_images, train_labels)
#
# <ipython-input-20-ab4561787ee0> in run(self, features, targets)
#     178
#     179         start = timeit.timeit()
# --> 180         self.train_batches(X_train, y_train)
#     181         end = timeit.timeit()
#     182         print("Time for training Neural Network using mini batches: {0}".format(end - start))
#
# <ipython-input-20-ab4561787ee0> in train_batches(self, images, targets)
#      75                 # Calculating the error
#      76                 train_error = self.calculate_error(final_outputs, batch_targets)
# ---> 77                 validation_error, validation_accuracy = self.calculate_validation_stats()
#      78                 print("Epoch {0}, Training Error {1:0.3f}, Validation Error {2:0.3f}, Validation Accuracy {3:0.3f}".format(i,                                                                     train_error, validation_error, validation_accuracy))
#      79
#
# <ipython-input-20-ab4561787ee0> in calculate_validation_stats(self)
#     133     def calculate_validation_stats(self):
#     134
# --> 135         validation_results = self.test(self.validation_features)
#     136         validation_error = (self.validation_targets - validation_results)**2
#     137         mean_validation_error = np.sum(validation_error)/self.validation_targets.shape[0]
#
# <ipython-input-20-ab4561787ee0> in test(self, features)
#     151     def test(self, features):
#     152
# --> 153         weights_hidden_layer1_in = np.dot(features, self.weights_input_to_hidden)
#     154         weights_hidden_layer1_out = self.sigmoid(weights_hidden_layer1_in)
#     155
#
# KeyboardInterrupt:

# %%
pred_outputs = network.test(test_images)
error = network.calculate_error(pred_outputs, test_labels)
print(error)
# Out:
# 0.903153644269
